# %% [markdown]
# # AoC

# %% [markdown]
# ## Day 1

# %% [markdown]
# ### Part 1

# %% [markdown]
# Test

# %%
pos = 50
movements =  ["L68", "L30", "R48", "L5", "R60", "L55", "L1", "L99", "R14", "L82"]
count = 0

for i in movements:
    if i[0]=="L":
        n = -int(i[1:])
    else:
        n = int(i[1:])
    pos = (pos+n)%100
    count+=1 if pos==0 else 0
    print(pos, count)
print(count)
# Out:
# 82 0
# 52 0
# 0 1
# 95 1
# 55 1
# 0 2
# 99 2
# 0 3
# 14 3
# 32 3
# 3

# %% [markdown]
# On input:

# %%
pos=50
count=0

with open("day1.txt") as file:
    while i:=file.readline()[:-1]:
        if i[0]=="L":
            n = -int(i[1:])
        else:
            n = int(i[1:])
        pos = (pos+n)%100
        count+=1 if pos==0 else 0

print(count)

#Only travel through the lines of the file one time, so complexity is Θ(n)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 4
#       1 pos=50
#       2 count=0
# ----> 4 with open("day1.txt") as file:
#       5     while i:=file.readline()[:-1]:
#       6         if i[0]=="L":
#
# File c:\Users\iker_\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'day1.txt'

# %% [markdown]
# Other classical option:

# %%
pos=50
count=0

with open("day1.txt") as file:
    l = file.read().splitlines()

for i in l:
    if i[0]=="L":
        n = -int(i[1:])
    else:
        n = int(i[1:])
    pos = (pos+n)%100
    count+=1 if pos==0 else 0
print(count)

# Have to go through the elements 2 times, one to extract the list and the other to do the calculation, so Θ(2n)
# Out:
# 1026

# %% [markdown]
# ### Part 2

# %% [markdown]
# Test:

# %%
pos = 50
movements =  ["L68", "L30", "R48", "L5", "R60", "L55", "L1", "L99", "R14", "L82"]
count = 0

for i in movements:
    if i[0]=="L":
        n = -int(i[1:])
    else:
        n = int(i[1:])
    new_pos = (pos+n)%100
    count+= abs(pos+n)//100
    if pos*(pos+n)<0 or pos+n==0:
        count+=1
    print(pos, n, pos+n, (pos+n)%100, abs(pos+n)//100, count)
    pos=new_pos

print(count)
# Out:
# 50 -68 -18 82 0 1
# 82 -30 52 52 0 1
# 52 48 100 0 1 2
# 0 -5 -5 95 0 2
# 95 60 155 55 1 3
# 55 -55 0 0 0 4
# 0 -1 -1 99 0 4
# 99 -99 0 0 0 5
# 0 14 14 14 0 5
# 14 -82 -68 32 0 6
# 6

# %% [markdown]
# Input:

# %%
pos=50
count=0

with open("day1.txt") as file:
    while i:=file.readline()[:-1]:
        if i[0]=="L":
            n = -int(i[1:])
        else:
            n = int(i[1:])
        new_pos = (pos+n)%100
        count+= abs(pos+n)//100
        if pos*(pos+n)<0 or pos+n==0:
            count+=1
        pos=new_pos
print(count)
# Out:
# 5923

# %% [markdown]
# ## Day 2

# %% [markdown]
# ### Part 1

# %% [markdown]
# Test:

# %%
def valid_id(id):
    sid = str(id)
    mid = len(sid)//2
    return sid[:mid]==sid[mid:]

# %%
input = "11-22,95-115,998-1012,1188511880-1188511890,222220-222224,1698522-1698528,446443-446449,38593856-38593862,565653-565659,824824821-824824827,2121212118-2121212124"
ranges = input.split(",")
count=0
for r in ranges:
    ids = r.split("-")
    for i in range(int(ids[0]),int(ids[1])+1,1):
        count+=i if valid_id(i) else 0
print(count)
# Out:
# 1227775554

# %% [markdown]
# input

# %%
with open("day2.txt") as f:
    input = f.readline()
ranges = input.split(",")
count=0
for r in ranges:
    ids = r.split("-")
    for i in range(int(ids[0]),int(ids[1])+1,1):
        count+=i if valid_id(i) else 0
print(count)
# Out:
# 54641809925

# %% [markdown]
# ### Part 2

# %% [markdown]
# Test

# %%
def valid_id2(id):
    sid = str(id)
    length=len(sid)
    # decomposition of length of string (prime decomposition can make this faster)
    for n in range(1,length//2+1):
        if length%n==0:
            elems = length//n
            l = [sid[n*i:n*i+n] for i in range(elems)]
            if l.count(l[0])==elems:
                       return True

# %%
input = "11-22,95-115,998-1012,1188511880-1188511890,222220-222224,1698522-1698528,446443-446449,38593856-38593862,565653-565659,824824821-824824827,2121212118-2121212124"
ranges = input.split(",")
count=0
for r in ranges:
    ids = r.split("-")
    for i in range(int(ids[0]),int(ids[1])+1,1):
        count+=i if valid_id2(i) else 0
print(count)
# Out:
# 4174379265

# %% [markdown]
# Input

# %%
with open("day2.txt") as f:
    input = f.readline()
ranges = input.split(",")
count=0
for r in ranges:
    ids = r.split("-")
    for i in range(int(ids[0]),int(ids[1])+1,1):
        count+=i if valid_id2(i) else 0
print(count) 
#inefficient as hell xD
# Out:
# 73694270688

# %% [markdown]
# ## Day 3

# %% [markdown]
# test

# %%
import numpy as np

# %%
input = """987654321111111
811111111111119
234234234234278
818181911112111"""

total_jolts = 0
for line in input.splitlines():
    bank = [int(c) for c in line] #n
    n1_idx = np.argmax(bank[:-1])
    n2_idx = np.argmax(bank[n1_idx+1:])
    jolts = int(str(bank[n1_idx])+str(bank[n1_idx+1+n2_idx]))
    total_jolts+=jolts
print(total_jolts)
# Out:
# 357

# %% [markdown]
# input

# %%
with open("day3.txt") as f:
    total_jolts = 0
    while line:=f.readline()[:-1]:
        bank = [int(c) for c in line]
        n1_idx = np.argmax(bank[:-1])
        n2_idx = np.argmax(bank[n1_idx+1:])
        jolts = int(str(bank[n1_idx])+str(bank[n1_idx+1+n2_idx]))
        total_jolts+=jolts
    print(total_jolts)
# Out:
# 17324

# %% [markdown]
# ### Part 2

# %% [markdown]
# test

# %%
input = """987654321111111
811111111111119
234234234234278
818181911112111"""

total_jolts = 0
for line in input.splitlines():
    bank = [int(c) for c in line]
    bank_copy = bank
    j=12
    list_idx = []
    while j>0:
        if j!=1:
            idx = np.argmax(bank[:-j+1])
        else:
            idx = np.argmax(bank)
        list_idx.append(idx)
        bank = bank[idx+1:]
        j-=1
    for i in range(1,12):
        list_idx[i] += list_idx[i-1]
    for i in range(12):
        list_idx[i]+=i
    jolts = int("".join([str(bank_copy[i]) for i in list_idx]))
    total_jolts+=jolts


print(total_jolts)
# Out:
# 3121910778619

# %% [markdown]
# input

# %%
with open("day3.txt") as f:
    total_jolts = 0
    while line:=f.readline()[:-1]:
        bank = [int(c) for c in line]
        bank_copy = bank
        j=12
        list_idx = []
        while j>0:
            if j!=1:
                idx = np.argmax(bank[:-j+1])
            else:
                idx = np.argmax(bank)
            list_idx.append(idx)
            bank = bank[idx+1:]
            j-=1
        for i in range(1,12):
            list_idx[i] += list_idx[i-1]
        for i in range(12):
            list_idx[i]+=i
        jolts = int("".join([str(bank_copy[i]) for i in list_idx]))
        total_jolts+=jolts
    print(total_jolts)
# Out:
# 171846613143331

# %% [markdown]
# ## Day 4

# %% [markdown]
# Test

# %%
input = """..@@.@@@@.
@@@.@.@.@@
@@@@@.@.@@
@.@@@@..@.
@@.@@@@.@@
.@@@@@@@.@
.@.@.@.@@@
@.@@@.@@@@
.@@@@@@@@.
@.@.@@@.@.
"""

grid = input.splitlines()

size=len(grid)
count=0
for row_pos in range(size):
    rows_to_look = [row_pos+i for i in range(-1,2) if (row_pos+i)>=0 and (row_pos+i)<size]
    for col_pos in range(len(col:=grid[row_pos])):
        if col[col_pos] == "@":
            cols_to_look = [col_pos+i for i in range(-1,2) if (col_pos+i)>=0 and (col_pos+i)<len(col)]
            l = []
            for i in rows_to_look:
                for j in cols_to_look:
                    l.append(grid[i][j])
            if l.count("@")<=4: #= beacuse I'm counting myself
                count+=1
print(count)
# Out:
# 13

# %% [markdown]
# Input

# %%
with open("day4.txt") as f:
    grid = f.read().splitlines()

size=len(grid)
count=0
for row_pos in range(size):
    rows_to_look = [row_pos+i for i in range(-1,2) if (row_pos+i)>=0 and (row_pos+i)<size]
    for col_pos in range(len(col:=grid[row_pos])):
        if col[col_pos] == "@":
            cols_to_look = [col_pos+i for i in range(-1,2) if (col_pos+i)>=0 and (col_pos+i)<len(col)]
            l = []
            for i in rows_to_look:
                for j in cols_to_look:
                    l.append(c:=grid[i][j])
            if l.count("@")<=4: #= beacuse I'm counting myself
                count+=1
print(count)
# Out:
# 1626

# %% [markdown]
# ### Part 2

# %% [markdown]
# Test

# %%
input = """..@@.@@@@.
@@@.@.@.@@
@@@@@.@.@@
@.@@@@..@.
@@.@@@@.@@
.@@@@@@@.@
.@.@.@.@@@
@.@@@.@@@@
.@@@@@@@@.
@.@.@@@.@.
"""

grid = input.splitlines()
height = len(grid)
width = len(grid[0])

# %%
def try_remove(a,b,grid):
    i_look = [a+n for n in range(-1,2) if (a+n)>=0 and (a+n)<height]
    j_look = [b+n for n in range(-1,2) if (b+n)>=0 and (b+n)<width]
    l = []
    for i in i_look:
        for j in j_look:
            l.append(grid[i][j])
    if l.count("@")<=4: #= beacuse I'm counting myself
        return True
    return False

# %%
total_count = 0
while True:
    count = 0
    for a in range(height):
        for b in range(width):
            if grid[a][b]=="@" and try_remove(a,b,grid):
                lin_list = list(grid[a])
                lin_list[b] = "."
                grid[a]= "".join(lin_list)
                count+=1
    total_count+=count
    if count==0:
        break
print(total_count)

# Hiper ineficiente, pero funciona, hay que probar en input
# Out:
# 43

# %% [markdown]
# Input

# %%
with open("day4.txt") as f:
    grid = f.read().splitlines()
height = len(grid)
width = len(grid[0])

# %%
total_count = 0
while True:
    count = 0
    for a in range(height):
        for b in range(width):
            if grid[a][b]=="@" and try_remove(a,b,grid):
                lin_list = list(grid[a])
                lin_list[b] = "."
                grid[a]= "".join(lin_list)
                count+=1
    total_count+=count
    if count==0:
        break
print(total_count)

# Pues no tarda mucho :D
# Out:
# 9173

# %% [markdown]
# ## Day 3

# %% [markdown]
# ### Part 1

# %% [markdown]
# Test

# %%
input = """3-5
10-14
16-20
12-18

1
5
8
11
17
32"""
all = input.split("\n") # m*n
idx = all.index("") # m*n
fresh_ranges = all[:idx] # m elements
ids = all[idx+1:] # n elements
# previous code has complexity O(2*m*n) ---- OK

#bruteforce
fresh = []
for e in fresh_ranges: # m
    s = int(e.split("-")[0])
    f = int(e.split("-")[1])
    for i in range(s,f+1): # depends on range size, lets call the mean u
        fresh.append(i)
# previous code has complexity O(m*u) ---- NOT OK
# The resulting fresh array has size m*u

count=0
for i in ids: # n
    if int(i) in fresh: # m*u
        count+=1
print(count)
# Previous result ahs complexity O(n*m*u) .......... too large ----- NOT OK
# Out:
# 3

# %% [markdown]
# need to find something else

# %%
input = """3-5
10-14
16-20
12-18

1
5
8
11
17
32"""
all = input.split("\n") # m+n
idx = all.index("") # m+n
fresh_ranges = all[:idx] # m elements
fresh_starts = []
fresh_ends = []
for e in fresh_ranges: #m
    s = int(e.split("-")[0])
    f = int(e.split("-")[1])
    fresh_starts.append(s)
    fresh_ends.append(f)
ids = all[idx+1:] # n elements
# previous code has complexity O(m+n) ---- OK

count=0
for i in ids: #n
    id = int(i)
    for j in range(len(fresh_starts)): #m
        if id>=fresh_starts[j] and id<=fresh_ends[j]:
            count+=1
            break
print(count)
# previous code has complexity (m*n) ---- OK
# Out:
# 3

# %% [markdown]
# Input

# %%
with open("day5.txt") as f:
    input = f.read()
all = input.split("\n") # m+n
idx = all.index("") # m+n
fresh_ranges = all[:idx] # m elements
fresh_starts = []
fresh_ends = []
for e in fresh_ranges: #m
    s = int(e.split("-")[0])
    f = int(e.split("-")[1])
    fresh_starts.append(s)
    fresh_ends.append(f)
ids = all[idx+1:] # n elements
# previous code has complexity O(m+n) ---- OK

count=0
for i in ids: #n
    id = int(i)
    for j in range(len(fresh_starts)): #m
        if id>=fresh_starts[j] and id<=fresh_ends[j]:
            count+=1
            break
print(count)
# previous code has complexity (m*n) ---- OK
# Out:
# 811

# %% [markdown]
# Part 2

# %%
import numpy as np

# %%
input = """3-5
10-14
16-20
12-18

1
5
8
11
17
32"""
all = input.split("\n") # m+n
idx = all.index("") # m+n
fresh_ranges = all[:idx] # m elements
fresh_starts = []
fresh_ends = []
for e in fresh_ranges: #m
    s = int(e.split("-")[0])
    f = int(e.split("-")[1])
    fresh_starts.append(s)
    fresh_ends.append(f)
fresh_starts = np.array(fresh_starts) #m
fresh_ends = np.array(fresh_ends) #m
sort_idx = np.argsort(fresh_starts) #m
fresh_starts = fresh_starts[sort_idx] #m
fresh_ends = fresh_ends[sort_idx] #m
# previous code has complexity O(9m+2n)=O(m+n) ---- OK

# %%
fresh_max=0
new_ranges = []
for i in range(fresh_starts.shape[0]): #m
    if fresh_starts[i] > fresh_max: 
        new_ranges.append((fresh_starts[i],f:=fresh_ends[i]))
    else:
        new_ranges[-1] = (new_ranges[-1][0],f:=fresh_ends[i])
    fresh_max=f
count=0
for i in new_ranges: #O(m)
    count+=i[1]-i[0]+1
print(count)
#previous code runs on O(m) ---- OK
# Out:
# 14

# %% [markdown]
# Input

# %%
import numpy as np
with open("day5.txt") as f:
    input = f.read()
all = input.split("\n") # m+n
idx = all.index("") # m+n
fresh_ranges = all[:idx] # m elements
fresh_starts = []
fresh_ends = []
for e in fresh_ranges: #m
    s = int(e.split("-")[0])
    f = int(e.split("-")[1])
    fresh_starts.append(s)
    fresh_ends.append(f)
fresh_starts = np.array(fresh_starts) #m
fresh_ends = np.array(fresh_ends) #m
sort_idx = np.argsort(fresh_starts) #m*logm
fresh_starts = fresh_starts[sort_idx] #m
fresh_ends = fresh_ends[sort_idx] #m
# previous code has complexity O(m*logm) ---- Decent
fresh_max=0
new_ranges = []
for i in range(fresh_starts.shape[0]): #m
    if fresh_starts[i] > fresh_max:
        new_ranges.append((fresh_starts[i],fresh_ends[i]))
    elif fresh_ends[i] > fresh_max:
        new_ranges[-1] = (new_ranges[-1][0],fresh_ends[i])
    else:
        continue
    fresh_max=fresh_ends[i]
count=0
for i in new_ranges: #O(m)
    count+=i[1]-i[0]+1
print(count)
#previous code runs on O(m*k+m)=O(m) ---- OK
# Out:
# 338189277144473

# %% [markdown]
# ## Day 6

# %% [markdown]
# Part 1

# %% [markdown]
# test

# %%
import re

# %%
def remove_empty(l):
    if l[0]=="" and l[-1]=="":
        return l[1:-1]
    elif l[0]=="":
        return l[1:]
    elif l[-1]=="":
        return l[:-1]
    else:
        return l

# %%
input = """123 328  51 64 
 45 64  387 23 
  6 98  215 314
*   +   *   +  """
input = input.split("\n") #n
input = input[::-1] #n
signs = re.split(r' +', input[0]) #m
signs = remove_empty(signs)
m = len(signs) #m
results = []
for i in range(m): #m
    if signs[i]=="+":
        results.append(0)
    else:
        results.append(1)
print(results)
for line in input[1:]: #n
    line_list = remove_empty(re.split(r' +', line))
    for i in range(m): #m
      if signs[i]=="+":
          results[i]+=int(line_list[i])
      else:
          results[i]*=int(line_list[i])
print(sum(results))
# Code runs in O(m*n)
# Out:
# [1, 0, 1, 0]
# 4277556

# %% [markdown]
# Input

# %%
with open("day6.txt") as f:
    input = f.read()
input = input.split("\n") #n
input = input[::-1] #n
signs = re.split(r' +', input[0]) #m
signs = remove_empty(signs)
m = len(signs) #m
results = []
for i in range(m): #m
    if signs[i]=="+":
        results.append(0)
    else:
        results.append(1)
for line in input[1:]: #n
    line_list = remove_empty(re.split(r' +', line))
    for i in range(m): #m
      if signs[i]=="+":
          results[i]+=int(line_list[i])
      else:
          results[i]*=int(line_list[i])
print(sum(results))
# Code runs in O(m*n)
# Out:
# 4412382293768

# %% [markdown]
# ### Part 2

# %%
input = """123 328  51 64 
 45 64  387 23 
  6 98  215 314
*   +   *   +  """
input = input.split("\n") #n
input = input[::-1] #n
signs = re.split(r' +', input[0]) #m
signs = remove_empty(signs)
m = len(signs) #m
results = []

#find separation indices
sep_idx = [0]
for j in range(len(input[1])): #m
    s = ""
    for i in range(1,len(input)): #n
        s+=input[i][j]
        if s=="   ":
            sep_idx.append(j)
# find indices in O(m*n)

total_count = 0
for i in range(len(sep_idx)): #m/3
    if i==0:
        idx = 0
    else:
        idx = sep_idx[i]+1
    if signs[i]=="+":
        count = 0
    else:
        count = 1
    if idx-1!=sep_idx[-1]:
        fin = sep_idx[i+1]
    else:
        fin = len(input[1])
    for j in range(idx, fin): #m
        s = input[1][j]+input[2][j]+input[3][j] #n
        numer = int(s[::-1])
        if signs[i]=="+":
            count+=numer
        else:
            count*=numer
    total_count += count
print(total_count)
# Complexity O(m*n)
# Out:
# 3263827

# %% [markdown]
# Input

# %%
with open("day6.txt") as f:
    input = f.read()
input = input.split("\n") #n
input = input[::-1] #n
signs = re.split(r' +', input[0]) #m
signs = remove_empty(signs)
m = len(signs) #m
results = []

#find separation indices
sep_idx = [0]
for j in range(len(input[1])): #m
    s = ""
    for i in range(1,len(input)): #n
        s+=input[i][j]
        if s=="    " and j-1 not in sep_idx:
            sep_idx.append(j)
# find indices in O(m*n)

total_count = 0
for i in range(len(sep_idx)): #m
    if i==0:
        idx = 0
    else:
        idx = sep_idx[i]+1
    if signs[i]=="+":
        count = 0
    else:
        count = 1
    if idx-1!=sep_idx[-1]:
        fin = sep_idx[i+1]
    else:
        fin = len(input[1])
    for j in range(idx, fin): #m
        s = input[1][j]+input[2][j]+input[3][j]+input[4][j] #n=4
        if s!="    ":
            numer = int(s[::-1])
        else:
            s = 0
        if signs[i]=="+":
            count+=numer
        else:
            count*=numer
    total_count += count
print(total_count)
# Complexity O(m)
# Out:
# 7858808482092

# %% [markdown]
# ## Day 7

# %% [markdown]
# ### Part 1

# %% [markdown]
# Input

# %%
input = """.......S.......
...............
.......^.......
...............
......^.^......
...............
.....^.^.^.....
...............
....^.^...^....
...............
...^.^...^.^...
...............
..^...^.....^..
...............
.^.^.^.^.^...^.
...............""" #size width=m x height=n
input = input.split("\n") # m*n
start = input[0].find("S") # m
input = [[i for i in j] for j in input] # m*n
input[1][start] = "|" 
input[0][start] = "|" #modify the first row for consitency in next code

folds = 0
splits = 0
for j in range(2,len(input),2): # I can ignore the odd rows, since they are always empty ---> n/2
    for i in range(len(input[j-2])): # m
        if input[j-2][i]=="|" and input[j][i]=="^": #^^ never appears
            splits+=1
            if input[j][i-1] != "|": #innecesarios estos ifs si no se usa folds
                input[j][i-1] = "|"
                input[j+1][i-1] = "|"
                folds+=1
            if input[j][i+1] != "|":
                input[j][i+1] = "|"
                input[j+1][i+1] = "|"
                folds+=1
        if input[j-2][i]=="|" and input[j][i]==".":
            input[j][i] = "|"
            input[j+1][i]= "|"
    #print(folds) #folds no mide splits
# prev m*n
print(splits)
# Out:
# 21

# %% [markdown]
# input

# %%
with open("day7.txt") as f:
    input = f.read()
input = input.split("\n") # m*n
start = input[0].find("S") # m
input = [[i for i in j] for j in input] # m*n
input[1][start] = "|" 
input[0][start] = "|" #modify the first row for consitency in next code

folds = 0
splits = 0
for j in range(2,len(input),2): # I can ignore the odd rows, since they are always empty ---> n/2
    for i in range(len(input[j-2])): # m
        if input[j-2][i]=="|" and input[j][i]=="^": #^^ never appears
            splits+=1
            if input[j][i-1] != "|": #innecesarios estos ifs si no se usa folds
                input[j][i-1] = "|"
                input[j+1][i-1] = "|"
                folds+=1
            if input[j][i+1] != "|":
                input[j][i+1] = "|"
                input[j+1][i+1] = "|"
                folds+=1
        if input[j-2][i]=="|" and input[j][i]==".":
            input[j][i] = "|"
            input[j+1][i]= "|"
    #print(folds) #folds no mide splits
# prev m*n
print(splits)
# Out:
# 1579

# %%
for j in input:
    print("".join(j))
# Out:
# ......................................................................|......................................................................
# ......................................................................|......................................................................
# .....................................................................|^|.....................................................................
# .....................................................................|.|.....................................................................
# ....................................................................|^|^|....................................................................
# ....................................................................|.|.|....................................................................
# ...................................................................|^|^|^|...................................................................
# ...................................................................|.|.|.|...................................................................
# ..................................................................|^|^|||^|..................................................................
# ..................................................................|.|.|||.|..................................................................
# .................................................................|^|^|^|^|^|.................................................................
# .................................................................|.|.|.|.|.|.................................................................
# ................................................................|^|^|||^|^|^|................................................................
# ................................................................|.|.|||.|.|.|................................................................
# ...............................................................|^|^|^|^|||^|^|...............................................................
# ...............................................................|.|.|.|.|||.|.|...............................................................
# ..............................................................|^||.||^|||^|^|^|..............................................................
# ..............................................................|.||.||.|||.|.|.|..............................................................
# .............................................................|^|||^|^|||||^|^|^|.............................................................
# .............................................................|.|||.|.|||||.|.|.|.............................................................
# ............................................................|^|^|^|||^||||.||^|^|............................................................
# ............................................................|.|.|.|||.||||.||.|.|............................................................
# ...........................................................|^|^|^|^|^|^|^|.|||^|^|...........................................................
# ...........................................................|.|.|.|.|.|.|.|.|||.|.|...........................................................
# ..........................................................|^|||^|^|^|^|^||.||||^|^|..........................................................
# ..........................................................|.|||.|.|.|.|.||.||||.|.|..........................................................
# .........................................................|^|||^|^|^|^|^|||^|||^|^|^|.........................................................
# .........................................................|.|||.|.|.|.|.|||.|||.|.|.|.........................................................
# ........................................................|^|^|^|^|^|^|^|^|||^|^|||^|^|........................................................
# ........................................................|.|.|.|.|.|.|.|.|||.|.|||.|.|........................................................
# .......................................................|^|^||.||^|^||.|.||^|^||||.||^|.......................................................
# .......................................................|.|.||.||.|.||.|.||.|.||||.||.|.......................................................
# ......................................................|^|||^|^|^|^|||.|.|||^|||^|.|^|^|......................................................
# ......................................................|.|||.|.|.|.|||.|.|||.|||.|.|.|.|......................................................
# .....................................................|^|^|^|^|^|^|||^|||^|^|||^|||^|^|^|.....................................................
# .....................................................|.|.|.|.|.|.|||.|||.|.|||.|||.|.|.|.....................................................
# ....................................................|^|||^|^|^|||^|^|^|^|||^|^|^|^||.||^|....................................................
# ....................................................|.|||.|.|.|||.|.|.|.|||.|.|.|.||.||.|....................................................
# ...................................................|^|^||.||^|||^|^|^|^|^|^|^|^|^|^|.|^|^|...................................................
# ...................................................|.|.||.||.|||.|.|.|.|.|.|.|.|.|.|.|.|.|...................................................
# ..................................................|^|^|^|.|^|^|^|^||.||^|^|^|^|||^|^|||^|^|..................................................
# ..................................................|.|.|.|.|.|.|.|.||.||.|.|.|.|||.|.|||.|.|..................................................
# .................................................|^||.||^|||^|^|^|||^||.||^|^|^|^|^|^|||^|^|.................................................
# .................................................|.||.||.|||.|.|.|||.||.||.|.|.|.|.|.|||.|.|.................................................
# ................................................|^|||^|^|||^|^|^|^||.||^|^|||^|^|||^|^|^|||^|................................................
# ................................................|.|||.|.|||.|.|.|.||.||.|.|||.|.|||.|.|.|||.|................................................
# ...............................................|^|^|^|^|^||.||^|^|||.|^|||^|^|^|^|||^|^|^|^|^|...............................................
# ...............................................|.|.|.|.|.||.||.|.|||.|.|||.|.|.|.|||.|.|.|.|.|...............................................
# ..............................................|^|^|^|||^|||.|||^|||^|^|^|||^|^|^|^||.|.||^|^|^|..............................................
# ..............................................|.|.|.|||.|||.|||.|||.|.|.|||.|.|.|.||.|.||.|.|.|..............................................
# .............................................|^||.||^|||^||.||^|^|^|^|^|^|||^||.|.||^|^|||^|^|^|.............................................
# .............................................|.||.||.|||.||.||.|.|.|.|.|.|||.||.|.||.|.|||.|.|.|.............................................
# ............................................|^|||^|^|||^|^|^|^|^|^|^|^||.||^|^|.|.|^||.||||^|^|^|............................................
# ............................................|.|||.|.|||.|.|.|.|.|.|.|.||.||.|.|.|.|.||.||||.|.|.|............................................
# ...........................................|^|^|^|^||||.||^|^|^|^|^|||^|.|^|^|^|||^|^|^|^|^|||^|^|...........................................
# ...........................................|.|.|.|.||||.||.|.|.|.|.|||.|.|.|.|.|||.|.|.|.|.|||.|.|...........................................
# ..........................................|^|||^|||^|^|^|^|||^|^|^|^|^|^|^|^||.||^|||^||.||^|||^|^|..........................................
# ..........................................|.|||.|||.|.|.|.|||.|.|.|.|.|.|.|.||.||.|||.||.||.|||.|.|..........................................
# .........................................|^|||^|^|^||.||^|^|^|^|^|^|^|||^|^|^|^|^|||^|||^|^|^|||^|^|.........................................
# .........................................|.|||.|.|.||.||.|.|.|.|.|.|.|||.|.|.|.|.|||.|||.|.|.|||.|.|.........................................
# ........................................|^|^|^|||^|^|^|||^||.||^|^|^|^|||^|||^|^|^|||^|^|^|^|^|||^|^|........................................
# ........................................|.|.|.|||.|.|.|||.||.||.|.|.|.|||.|||.|.|.|||.|.|.|.|.|||.|.|........................................
# .......................................|^|||^|^||.||^|||^|||^|^||.|.|.||^|^|^|^|^|^|||^|||^|^|^|||^|^|.......................................
# .......................................|.|||.|.||.||.|||.|||.|.||.|.|.||.|.|.|.|.|.|||.|||.|.|.|||.|.|.......................................
# ......................................|^|||^|||^|^|||^|||^|^|^|||^|.|^|^|^|^||.||^|^|^|^|^|||^|^|^|^|^|......................................
# ......................................|.|||.|||.|.|||.|||.|.|.|||.|.|.|.|.|.||.||.|.|.|.|.|||.|.|.|.|.|......................................
# .....................................|^|||^|^|^|^|||^|||^|^|^|||^|||^|||^|^|^|.|^|^|^|^||.||^|^|^||.||^|.....................................
# .....................................|.|||.|.|.|.|||.|||.|.|.|||.|||.|||.|.|.|.|.|.|.|.||.||.|.|.||.||.|.....................................
# ....................................|^|||^|||^||.||||^||.||^|||||^|||^|^||.||^|||^|||^|||^|||^|||^|^|^|^|....................................
# ....................................|.|||.|||.||.||||.||.||.|||||.|||.|.||.||.|||.|||.|||.|||.|||.|.|.|.|....................................
# ...................................|^|||||^|^|^|^|||^|||^|^|^|^|^|||^|^|^|^|^|^|^|||^|^|||^|^|^|^|||^|||^|...................................
# ...................................|.|||||.|.|.|.|||.|||.|.|.|.|.|||.|.|.|.|.|.|.|||.|.|||.|.|.|.|||.|||.|...................................
# ..................................|^|||||^|^|^|^|||^|^|^|^|^|||^|^||.||^|||^||.|.||^|||^|^|^|^|^|^|^|^|^|^|..................................
# ..................................|.|||||.|.|.|.|||.|.|.|.|.|||.|.||.||.|||.||.|.||.|||.|.|.|.|.|.|.|.|.|.|..................................
# .................................|^|^|^|^|||^|||^|^||.|.|.||^|^||.||^|^||||.||^|^|||^|||^|^|^|||^|||^|^|^|^|.................................
# .................................|.|.|.|.|||.|||.|.||.|.|.||.|.||.||.|.||||.||.|.|||.|||.|.|.|||.|||.|.|.|.|.................................
# ................................|^|^|^|^|^|||^|^|^|||^|.|.|^|^|||.||.||^|^|^||.||^|^|^|||^|^|^|^|||^|^|^|||^|................................
# ................................|.|.|.|.|.|||.|.|.|||.|.|.|.|.|||.||.||.|.|.||.||.|.|.|||.|.|.|.|||.|.|.|||.|................................
# ...............................|^|^||.||^|^|^|^|||^|||^|^|^|^|^|||^|^|||^|^|^|^|^|||^|^|^|^|^|^|^|^|^|^|^|||^|...............................
# ...............................|.|.||.||.|.|.|.|||.|||.|.|.|.|.|||.|.|||.|.|.|.|.|||.|.|.|.|.|.|.|.|.|.|.|||.|...............................
# ..............................|^|||^|.|^|^|^|^|||^|^|^|||^|^|^|^|^|^|^||.||^|^|^|^|^|^||.||^|||^|^|^|^|^|^|||^|..............................
# ..............................|.|||.|.|.|.|.|.|||.|.|.|||.|.|.|.|.|.|.||.||.|.|.|.|.|.||.||.|||.|.|.|.|.|.|||.|..............................
# .............................|^|||||^|||^|^|||^|||^|^|^|^|^|||^|||^||.||^|^|^|||^|^|^|^|.||.||^|^|^|^|^|^|||||^|.............................
# .............................|.|||||.|||.|.|||.|||.|.|.|.|.|||.|||.||.||.|.|.|||.|.|.|.|.||.||.|.|.|.|.|.|||||.|.............................
# ............................|^|^|^|^|^||.||^||.|||.||^|||^|||^|^|||^|^|^|^|^|||||^|^|||^|^|^|^|||^|||^|||^|||^|^|............................
# ............................|.|.|.|.|.||.||.||.|||.||.|||.|||.|.|||.|.|.|.|.|||||.|.|||.|.|.|.|||.|||.|||.|||.|.|............................
# ...........................|^|^|^|^|^|^|.|^|||^|||^|^|^||.||^|^|||^|^|^|^|^|^|^|^|^|||^|^|^|^|^|||^|^|||^|||^|^|^|...........................
# ...........................|.|.|.|.|.|.|.|.|||.|||.|.|.||.||.|.|||.|.|.|.|.|.|.|.|.|||.|.|.|.|.|||.|.|||.|||.|.|.|...........................
# ..........................|^|||^||.||^|^||.||^|^|^|^|||^|^||.|.||^|||^|||^|^|^|||^|||||^|^|^|||^|||^|^|^|||^|||^|^|..........................
# ..........................|.|||.||.||.|.||.||.|.|.|.|||.|.||.|.||.|||.|||.|.|.|||.|||||.|.|.|||.|||.|.|.|||.|||.|.|..........................
# .........................|^|^|||^|.|^|^|^|^|^|||^|^|^|^|||^|^|^|^|||^|^|^|^|^|^|^|^|||||^|^|||^|||^|^|^|^|^|^|^|^|^|.........................
# .........................|.|.|||.|.|.|.|.|.|.|||.|.|.|.|||.|.|.|.|||.|.|.|.|.|.|.|.|||||.|.|||.|||.|.|.|.|.|.|.|.|.|.........................
# ........................|^|||^|||^|||^||.|.|.|||.||^|||^|^|^||.||^|||^|^||.||^||.||^|^|^|||^|^|^|^|^|||^|||^|^|||^|^|........................
# ........................|.|||.|||.|||.||.|.|.|||.||.|||.|.|.||.||.|||.|.||.||.||.||.|.|.|||.|.|.|.|.|||.|||.|.|||.|.|........................
# .......................|^|^|^|^|^|^|^|^|^|.|.|^|^||.||^|^|||^|.||.|||.||^|^|^|^|^|^|^|^|||^|||^||.||^|^|^||.||^|^|||^|.......................
# .......................|.|.|.|.|.|.|.|.|.|.|.|.|.||.||.|.|||.|.||.|||.||.|.|.|.|.|.|.|.|||.|||.||.||.|.|.||.||.|.|||.|.......................
# ......................|^|^||.||^|||^|^|^|^|^|^|||^|.||.|.||^|^|^|^|||^|||^|^|^|||^|||^|||^|||^|^|.|^|||^|^|^|^|||^|||^|......................
# ......................|.|.||.||.|||.|.|.|.|.|.|||.|.||.|.||.|.|.|.|||.|||.|.|.|||.|||.|||.|||.|.|.|.|||.|.|.|.|||.|||.|......................
# .....................|^|||^|.|^|||^|^|^|^||.||^|^||.||.|^|^||.|.||^|^|^|^|||^|^|^|^|^|||||^|^||.|.|.||^|^|^|^|||||^|^|^|.....................
# .....................|.|||.|.|.|||.|.|.|.||.||.|.||.||.|.|.||.|.||.|.|.|.|||.|.|.|.|.|||||.|.||.|.|.||.|.|.|.|||||.|.|.|.....................
# ....................|^|^|||^|^|^|^|^|^|^|^|^|^|^|^|^|^|^|^|^|.|^|^|||^||.||||^|^|||^|^|^|^||.||^|^|^||.||^|^|||||^||.||^|....................
# ....................|.|.|||.|.|.|.|.|.|.|.|.|.|.|.|.|.|.|.|.|.|.|.|||.||.||||.|.|||.|.|.|.||.||.|.|.||.||.|.|||||.||.||.|....................
# ...................|^|^|||^|^|||^|^|^|^|||^|^|||^|^|||^|||^|||^|^|^|^|||.|^|||^|^|^|^|^||.||.|||^|^|||^|||^|^|^|^|^|^|^|^|...................
# ...................|.|.|||.|.|||.|.|.|.|||.|.|||.|.|||.|||.|||.|.|.|.|||.|.|||.|.|.|.|.||.||.|||.|.|||.|||.|.|.|.|.|.|.|.|...................
# ..................|^|^|^|||^|^|^|^|^|^|||||^|||||^|^|^|^|^|||^|||^|^|||^|^|^|^|^|^|||^|||.|^|^|^|^|^|^|||^|^|||^|^|||^|^|^|..................
# ..................|.|.|.|||.|.|.|.|.|.|||||.|||||.|.|.|.|.|||.|||.|.|||.|.|.|.|.|.|||.|||.|.|.|.|.|.|.|||.|.|||.|.|||.|.|.|..................
# .................|^|^|^|^|^|^|||^|^|^|^|^|^|^|^|||^|^||.|.||^|||||^|^|||^|^|^|^|^|^|||^|^|^|^|^|^||.||^||.|.||||^|^|||^|^|^|.................
# .................|.|.|.|.|.|.|||.|.|.|.|.|.|.|.|||.|.||.|.||.|||||.|.|||.|.|.|.|.|.|||.|.|.|.|.|.||.||.||.|.||||.|.|||.|.|.|.................
# ................|^|^|||^|^|||^|^|^||.||^|||^|^|^|||^|||^|^||.||^|||^|||^|^|^|^||.||^|^|^|^||.||^|||^|^|^|^|.|||^|^|||^|^|^|^|................
# ................|.|.|||.|.|||.|.|.||.||.|||.|.|.|||.|||.|.||.||.|||.|||.|.|.|.||.||.|.|.|.||.||.|||.|.|.|.|.|||.|.|||.|.|.|.|................
# ...............|^|^|^|^|^|^|^|^||.||^|^|^|^|^||.||||^|^|||^|^|^|^|||^|||^|^||.||^|||^|^|^|^|^|^|||||^|||^|^|||^|^|||^|^|^|^|^|...............
# ...............|.|.|.|.|.|.|.|.||.||.|.|.|.|.||.||||.|.|||.|.|.|.|||.|||.|.||.||.|||.|.|.|.|.|.|||||.|||.|.|||.|.|||.|.|.|.|.|...............
# ..............|^|^|^|||^|^|||^|^|^|^|^|^|^|^|^|^|||^|^|||||^|||^|^||.||^|^|^|.|^|^|^|^|^|^|^|^|^|||||^|^|||^|||^|||||^|^|^|^|^|..............
# ..............|.|.|.|||.|.|||.|.|.|.|.|.|.|.|.|.|||.|.|||||.|||.|.||.||.|.|.|.|.|.|.|.|.|.|.|.|.|||||.|.|||.|||.|||||.|.|.|.|.|..............
# .............|^|^|||^|^|||^|^|^|^|^|^|^|^|||^|^|^|^|^|^|^|^|^|||^|^|^|^|||^|^|||^|||^|^|^||.||^|||^|^|||^|^|||^|^|||||^|^|^|||^|.............
# .............|.|.|||.|.|||.|.|.|.|.|.|.|.|||.|.|.|.|.|.|.|.|.|||.|.|.|.|||.|.|||.|||.|.|.||.||.|||.|.|||.|.|||.|.|||||.|.|.|||.|.............
# ............|^|^|^|||^|^|^|^|^|||^|^|^|||^|^|^|^|^|^|||^|^|^|||^|^|^|^||||.|.||^|^|^|^||.||^|^|^|||^|||^|^|||^|||^|^|^|^|^|^|^|^|............
# ............|.|.|.|||.|.|.|.|.|||.|.|.|||.|.|.|.|.|.|||.|.|.|||.|.|.|.||||.|.||.|.|.|.||.||.|.|.|||.|||.|.|||.|||.|.|.|.|.|.|.|.|............
# ...........|^|||^|^|||^|^|^|||^|||^|^|||^|^|^|^||.||^|^|^|^|^|^|||^|^|^|^|^|.|^|^|||^|^|^|^|^|^|^|||^|^|^|^|^||||.|.|.||^|||^|||^|...........
# ...........|.|||.|.|||.|.|.|||.|||.|.|||.|.|.|.||.||.|.|.|.|.|.|||.|.|.|.|.|.|.|.|||.|.|.|.|.|.|.|||.|.|.|.|.||||.|.|.||.|||.|||.|...........
# ..........|^|||^||.||^|^|^|^|^|||^|^|^|^|^|||^|^|^|^|||^|||^||.||||^|||^|^|^|^|||^|^|^||.||^|^|^|||||^|||^|^|||||.|^|^|^|^|^|^|^|^|..........
# ..........|.|||.||.||.|.|.|.|.|||.|.|.|.|.|||.|.|.|.|||.|||.||.||||.|||.|.|.|.|||.|.|.||.||.|.|.|||||.|||.|.|||||.|.|.|.|.|.|.|.|.|..........
# .........|^|^|^|^|^|^|^|^|^|^|^||.||^|^|||^|||^|||^|^|^|||||^|.|^|^|^|||^||.||^|||^|^|^|^|||^|^|^|^|^|^||.||^|^|^|^|^|^||.||^||.||^|.........
# .........|.|.|.|.|.|.|.|.|.|.|.||.||.|.|||.|||.|||.|.|.|||||.|.|.|.|.|||.||.||.|||.|.|.|.|||.|.|.|.|.|.||.||.|.|.|.|.|.||.||.||.||.|.........
# ........|^|||^||.||^|^|^|^|||^|||^|^|^|||^|^|||^||.|.|.||^|^|^|^|^|^|||^|^|^||.||^|||^|^|^|||^|^|^||.|.||.||.||^|^|||^|^|.|^|||.|^|^|........
# ........|.|||.||.||.|.|.|.|||.|||.|.|.|||.|.|||.||.|.|.||.|.|.|.|.|.|||.|.|.||.||.|||.|.|.|||.|.|.||.|.||.||.||.|.|||.|.|.|.|||.|.|.|........
# .......|^|^|^|||^|^|^|^||.||^|^|^|^|^|^|^|^|^|^|||^|.|.|^|^||.||^|||^|^|^|||^|^||.||||^|||^|^|||^|||^|^|^|||^|^|^|^||.||^|||^|||^|^|^|.......
# .......|.|.|.|||.|.|.|.||.||.|.|.|.|.|.|.|.|.|.|||.|.|.|.|.||.||.|||.|.|.|||.|.||.||||.|||.|.|||.|||.|.|.|||.|.|.|.||.||.|||.|||.|.|.|.......
# ......|^|^||.|||.||^|^|^|^|^||.|.||^||.||^|||^|||||^|^|^|^|^|.|^|^|^|||^|||^|^|||.|^|^|^|^|^||||.||^||.||^|^|^|^|||^|.|^|||^|^|^|||^|^|......
# ......|.|.||.|||.||.|.|.|.|.||.|.||.||.||.|||.|||||.|.|.|.|.|.|.|.|.|||.|||.|.|||.|.|.|.|.|.||||.||.||.||.|.|.|.|||.|.|.|||.|.|.|||.|.|......
# .....|^|^|||^|||^|^|^|^||.|.||^|^|^|^|^|||^|^|||^|||^|^|||^|^|||^|^|||^|^|^||.|||.||^|^|^|^|||^|^|^|||^|||^|||^|^|||^|^|^|^||.|.||^|^|^|.....
# .....|.|.|||.|||.|.|.|.||.|.||.|.|.|.|.|||.|.|||.|||.|.|||.|.|||.|.|||.|.|.||.|||.||.|.|.|.|||.|.|.|||.|||.|||.|.|||.|.|.|.||.|.||.|.|.|.....
# ....|^|^|||^|||||^|^|||^|^|^||.||^|^|^|^|^|^|||||^|^|^|^|||^|^|^||.||^|^|^|||^|^|^|||^|^||.||^|||^|||^|^|||^|^|||^|^|^|^|^|^|^|^|^|||^|^|....
# ....|.|.|||.|||||.|.|||.|.|.||.||.|.|.|.|.|.|||||.|.|.|.|||.|.|.||.||.|.|.|||.|.|.|||.|.||.||.|||.|||.|.|||.|.|||.|.|.|.|.|.|.|.|.|||.|.|....
# ...|^|^|^|^|||^|^|^|^|^||.||^|^|^|^|^|||^||.||^|^|^|^|||^|^|^||.||.||.||^|^|^|||^|^|||^|^|^|||^|^|||||^|||^|^|||^|^|^|||^|^|^|^|^|||||^|^|...
# ...|.|.|.|.|||.|.|.|.|.||.||.|.|.|.|.|||.||.||.|.|.|.|||.|.|.||.||.||.||.|.|.|||.|.|||.|.|.|||.|.|||||.|||.|.|||.|.|.|||.|.|.|.|.|||||.|.|...
# ..|^|^||.||^|||^|||^|^|||^|^|^|^|^|^|^||.||^|^|^|^|||^|^||.||^|.|^|^|^|^||.|.||^|^|^|||^||.||||^|||^|^|^|^|^|||||^|^|^|^|^|^|||^|^|^|^|^|^|..
# ..|.|.||.||.|||.|||.|.|||.|.|.|.|.|.|.||.||.|.|.|.|||.|.||.||.|.|.|.|.|.||.|.||.|.|.|||.||.||||.|||.|.|.|.|.|||||.|.|.|.|.|.|||.|.|.|.|.|.|..
# .|^|^|^|^|^|^|^|^||.||^|^|^|^|||^|^||.||^|^|||^|^|||^||.||.||.||^|||^|^|^|^|^|^|^|^|||^|^|.|^|^|^|||^|^|^|^|^|^|^|||^|^||.||^|^||.||^|^|^|^|.
# .|.|.|.|.|.|.|.|.||.||.|.|.|.|||.|.||.||.|.|||.|.|||.||.||.||.||.|||.|.|.|.|.|.|.|.|||.|.|.|.|.|.|||.|.|.|.|.|.|.|||.|.||.||.|.||.||.|.|.|.|.
# |^|^||.||^|^|^|||^|^|^|^|^|^|^|||^|^|.|^|^|||^|^|||^|^|^|||^|^|^|||^|^|^|||^||.||^|^|^|^|||^|^||.||^|||^|^|^||.||^|^|||^|^|^|^|||^|^|^|||^|^|
# |.|.||.||.|.|.|||.|.|.|.|.|.|.|||.|.|.|.|.|||.|.|||.|.|.|||.|.|.|||.|.|.|||.||.||.|.|.|.|||.|.||.||.|||.|.|.||.||.|.|||.|.|.|.|||.|.|.|||.|.|

# %% [markdown]
# ### Part 2

# %%
input = """.......S.......
...............
.......^.......
...............
......^.^......
...............
.....^.^.^.....
...............
....^.^...^....
...............
...^.^...^.^...
...............
..^...^.....^..
...............
.^.^.^.^.^...^.
...............""" #size width=m x height=n
input = input.split("\n") # m*n
start = input[0].find("S") # m
input = [[i for i in j] for j in input] # m*n
input[1][start] = "|" 
input[0][start] = "|" #modify the first row for consitency in next code

splits = 0
for j in range(2,len(input),2): # I can ignore the odd rows, since they are always empty ---> n/2
    for i in range(len(input[j-2])): # m
        if input[j-2][i]=="|" and input[j][i]=="^": #^^ never appears
            splits+=1
            input[j][i-1] = "|"
            input[j+1][i-1] = "|"
            input[j][i+1] = "|"
            input[j+1][i+1] = "|"
        if input[j-2][i]=="|" and input[j][i]==".":
            input[j][i] = "|"
            input[j+1][i]= "|"
    #print(folds) #folds no mide splits
# prev m*n
for j in input:
    print("".join(j))
# Out:
# .......|.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# .....|.|.|.....
# ....|^|^|^|....
# ....|.|.|.|....
# ...|^|^|||^|...
# ...|.|.|||.|...
# ..|^|^|||^|^|..
# ..|.|.|||.|.|..
# .|^|||^||.||^|.
# .|.|||.||.||.|.
# |^|^|^|^|^|||^|
# |.|.|.|.|.|||.|

# %%
# propagating bottom to top
splits_generated = {} #key is a known splitter, and value is the number of lines it generates
# last line generates as many lines as active splitters
j = len(input)-2
for i in range(len(input[j])):
    if input[j][i]=="^" and input[j-1][i]=="|": #active splitter
        splits_generated[(j,i)]=2
# rest of the lines
for j in range(len(input)-4,0,-2):
    for i in range(len(input[j])):
        if input[j][i]=="^" and input[j-1][i]=="|": #active splitter
            # left lines
            left = 1
            for l in range(j+2,len(input),2):
                if (l,i-1) in splits_generated:
                    left = splits_generated[(l,i-1)]
                    break
            # right lines
            right = 1
            for l in range(j+2,len(input),2):
                if (l,i+1) in splits_generated:
                    right = splits_generated[(l,i+1)]
                    break
            splits_generated[(j,i)]=left+right
print(splits_generated[(2,start)])
# Out:
# 40

# %% [markdown]
# input

# %%
with open("day7.txt") as f:
    input = f.read()
input = input.split("\n") # m*n
start = input[0].find("S") # m
input = [[i for i in j] for j in input] # m*n
input[1][start] = "|" 
input[0][start] = "|" #modify the first row for consitency in next code

folds = 0
splits = 0
for j in range(2,len(input),2): # I can ignore the odd rows, since they are always empty ---> n/2
    for i in range(len(input[j-2])): # m
        if input[j-2][i]=="|" and input[j][i]=="^": #^^ never appears
            splits+=1
            if input[j][i-1] != "|": #innecesarios estos ifs si no se usa folds
                input[j][i-1] = "|"
                input[j+1][i-1] = "|"
                folds+=1
            if input[j][i+1] != "|":
                input[j][i+1] = "|"
                input[j+1][i+1] = "|"
                folds+=1
        if input[j-2][i]=="|" and input[j][i]==".":
            input[j][i] = "|"
            input[j+1][i]= "|"
    #print(folds) #folds no mide splits
print(splits)
# Complexity O(m*n)
# Out:
# 1579

# %%
import time

# %%
start_time = time.time()
# propagating bottom to top
splits_generated = {} #key is a known splitter, and value is the number of lines it generates
# last line generates as many lines as active splitters
j = len(input)-2
for i in range(len(input[j])): # m
    if input[j][i]=="^" and input[j-1][i]=="|": #active splitter
        splits_generated[(j,i)]=2
# rest of the lines
for j in range(len(input)-4,0,-2): # n
    for i in range(len(input[j])): # m
        if input[j][i]=="^" and input[j-1][i]=="|": #active splitter
            # left lines
            left = 1
            for l in range(j+2,len(input),2): # n/2 is the mean of max values to look, which leads to O(n^2*m) :(( It works because normally this is O(3) by mean
                if (l,i-1) in splits_generated:
                    left = splits_generated[(l,i-1)]
                    break
            # right lines
            right = 1
            for l in range(j+2,len(input),2):
                if (l,i+1) in splits_generated:
                    right = splits_generated[(l,i+1)]
                    break
            splits_generated[(j,i)]=left+right
print(splits_generated[(2,start)])
end_time=time.time()
print(end_time-start_time)
# Out:
# 13418215871354
# 0.001996755599975586

# %% [markdown]
# Other way to avoid the O(n^2)

# %%
input = """.......S.......
...............
.......^.......
...............
......^.^......
...............
.....^.^.^.....
...............
....^.^...^....
...............
...^.^...^.^...
...............
..^...^.....^..
...............
.^.^.^.^.^...^.
...............""" #size width=m x height=n
input = input.split("\n") # m*n
start = input[0].find("S") # m
input = [[i for i in j] for j in input] # m*n
input[1][start] = "|" 
input[0][start] = "|" #modify the first row for consitency in next code

splits = 0
for j in range(2,len(input),2): # I can ignore the odd rows, since they are always empty ---> n/2
    for i in range(len(input[j-2])): # m
        if input[j-2][i]=="|" and input[j][i]=="^": #^^ never appears
            splits+=1
            input[j][i-1] = "|"
            input[j+1][i-1] = "|"
            input[j][i+1] = "|"
            input[j+1][i+1] = "|"
        if input[j-2][i]=="|" and input[j][i]==".":
            input[j][i] = "|"
            input[j+1][i]= "|"
    #print(folds) #folds no mide splits
# prev m*n
input = [input[j] for j in range(0,len(input),2)]
for j in input:
    print("".join(j))
# Out:
# .......|.......
# ......|^|......
# .....|^|^|.....
# ....|^|^|^|....
# ...|^|^|||^|...
# ..|^|^|||^|^|..
# .|^|||^||.||^|.
# |^|^|^|^|^|||^|

# %%
for i in range(len(input[-1])): #m
    if input[-1][i] == "|":
        input[-1][i] = "1"
for j in range(len(input)-1,-1,-1): #n
    for i in range(len(input[j])): #m
        if input[j][i]=="|" and input[j+1][i]=="^":
            input[j][i] = str(int(input[j+1][i-1])+int(input[j+1][i+1]))
        if input[j][i]=="|" and input [j+1][i]!=".":
            input[j][i] = input[j+1][i]
# Complexity is O(m*n) :DDDDDd
for j in input:
    print("".join(j))
# Out:
# .......40.......
# ......25^15......
# .....17^8^7.....
# ....10^7^1^6....
# ...5^5^212^4...
# ..4^1^421^1^3..
# .2^212^21.11^2.
# 1^1^1^1^1^111^1

# %% [markdown]
# input

# %%
with open("day7.txt") as f:
    input = f.read()
input = input.split("\n") # m*n
start = input[0].find("S") # m
input = [[i for i in j] for j in input] # m*n
input[1][start] = "|" 
input[0][start] = "|" #modify the first row for consitency in next code

folds = 0
splits = 0
for j in range(2,len(input),2): # I can ignore the odd rows, since they are always empty ---> n/2
    for i in range(len(input[j-2])): # m
        if input[j-2][i]=="|" and input[j][i]=="^": #^^ never appears
            splits+=1
            if input[j][i-1] != "|": #innecesarios estos ifs si no se usa folds
                input[j][i-1] = "|"
                input[j+1][i-1] = "|"
                folds+=1
            if input[j][i+1] != "|":
                input[j][i+1] = "|"
                input[j+1][i+1] = "|"
                folds+=1
        if input[j-2][i]=="|" and input[j][i]==".":
            input[j][i] = "|"
            input[j+1][i]= "|"
    #print(folds) #folds no mide splits
print(splits)
# Complexity O(m*n)
input = [input[j] for j in range(0,len(input),2)]
for j in input:
    print("".join(j))
# Out:
# 1579
# ......................................................................|......................................................................
# .....................................................................|^|.....................................................................
# ....................................................................|^|^|....................................................................
# ...................................................................|^|^|^|...................................................................
# ..................................................................|^|^|||^|..................................................................
# .................................................................|^|^|^|^|^|.................................................................
# ................................................................|^|^|||^|^|^|................................................................
# ...............................................................|^|^|^|^|||^|^|...............................................................
# ..............................................................|^||.||^|||^|^|^|..............................................................
# .............................................................|^|||^|^|||||^|^|^|.............................................................
# ............................................................|^|^|^|||^||||.||^|^|............................................................
# ...........................................................|^|^|^|^|^|^|^|.|||^|^|...........................................................
# ..........................................................|^|||^|^|^|^|^||.||||^|^|..........................................................
# .........................................................|^|||^|^|^|^|^|||^|||^|^|^|.........................................................
# ........................................................|^|^|^|^|^|^|^|^|||^|^|||^|^|........................................................
# .......................................................|^|^||.||^|^||.|.||^|^||||.||^|.......................................................
# ......................................................|^|||^|^|^|^|||.|.|||^|||^|.|^|^|......................................................
# .....................................................|^|^|^|^|^|^|||^|||^|^|||^|||^|^|^|.....................................................
# ....................................................|^|||^|^|^|||^|^|^|^|||^|^|^|^||.||^|....................................................
# ...................................................|^|^||.||^|||^|^|^|^|^|^|^|^|^|^|.|^|^|...................................................
# ..................................................|^|^|^|.|^|^|^|^||.||^|^|^|^|||^|^|||^|^|..................................................
# .................................................|^||.||^|||^|^|^|||^||.||^|^|^|^|^|^|||^|^|.................................................
# ................................................|^|||^|^|||^|^|^|^||.||^|^|||^|^|||^|^|^|||^|................................................
# ...............................................|^|^|^|^|^||.||^|^|||.|^|||^|^|^|^|||^|^|^|^|^|...............................................
# ..............................................|^|^|^|||^|||.|||^|||^|^|^|||^|^|^|^||.|.||^|^|^|..............................................
# .............................................|^||.||^|||^||.||^|^|^|^|^|^|||^||.|.||^|^|||^|^|^|.............................................
# ............................................|^|||^|^|||^|^|^|^|^|^|^|^||.||^|^|.|.|^||.||||^|^|^|............................................
# ...........................................|^|^|^|^||||.||^|^|^|^|^|||^|.|^|^|^|||^|^|^|^|^|||^|^|...........................................
# ..........................................|^|||^|||^|^|^|^|||^|^|^|^|^|^|^|^||.||^|||^||.||^|||^|^|..........................................
# .........................................|^|||^|^|^||.||^|^|^|^|^|^|^|||^|^|^|^|^|||^|||^|^|^|||^|^|.........................................
# ........................................|^|^|^|||^|^|^|||^||.||^|^|^|^|||^|||^|^|^|||^|^|^|^|^|||^|^|........................................
# .......................................|^|||^|^||.||^|||^|||^|^||.|.|.||^|^|^|^|^|^|||^|||^|^|^|||^|^|.......................................
# ......................................|^|||^|||^|^|||^|||^|^|^|||^|.|^|^|^|^||.||^|^|^|^|^|||^|^|^|^|^|......................................
# .....................................|^|||^|^|^|^|||^|||^|^|^|||^|||^|||^|^|^|.|^|^|^|^||.||^|^|^||.||^|.....................................
# ....................................|^|||^|||^||.||||^||.||^|||||^|||^|^||.||^|||^|||^|||^|||^|||^|^|^|^|....................................
# ...................................|^|||||^|^|^|^|||^|||^|^|^|^|^|||^|^|^|^|^|^|^|||^|^|||^|^|^|^|||^|||^|...................................
# ..................................|^|||||^|^|^|^|||^|^|^|^|^|||^|^||.||^|||^||.|.||^|||^|^|^|^|^|^|^|^|^|^|..................................
# .................................|^|^|^|^|||^|||^|^||.|.|.||^|^||.||^|^||||.||^|^|||^|||^|^|^|||^|||^|^|^|^|.................................
# ................................|^|^|^|^|^|||^|^|^|||^|.|.|^|^|||.||.||^|^|^||.||^|^|^|||^|^|^|^|||^|^|^|||^|................................
# ...............................|^|^||.||^|^|^|^|||^|||^|^|^|^|^|||^|^|||^|^|^|^|^|||^|^|^|^|^|^|^|^|^|^|^|||^|...............................
# ..............................|^|||^|.|^|^|^|^|||^|^|^|||^|^|^|^|^|^|^||.||^|^|^|^|^|^||.||^|||^|^|^|^|^|^|||^|..............................
# .............................|^|||||^|||^|^|||^|||^|^|^|^|^|||^|||^||.||^|^|^|||^|^|^|^|.||.||^|^|^|^|^|^|||||^|.............................
# ............................|^|^|^|^|^||.||^||.|||.||^|||^|||^|^|||^|^|^|^|^|||||^|^|||^|^|^|^|||^|||^|||^|||^|^|............................
# ...........................|^|^|^|^|^|^|.|^|||^|||^|^|^||.||^|^|||^|^|^|^|^|^|^|^|^|||^|^|^|^|^|||^|^|||^|||^|^|^|...........................
# ..........................|^|||^||.||^|^||.||^|^|^|^|||^|^||.|.||^|||^|||^|^|^|||^|||||^|^|^|||^|||^|^|^|||^|||^|^|..........................
# .........................|^|^|||^|.|^|^|^|^|^|||^|^|^|^|||^|^|^|^|||^|^|^|^|^|^|^|^|||||^|^|||^|||^|^|^|^|^|^|^|^|^|.........................
# ........................|^|||^|||^|||^||.|.|.|||.||^|||^|^|^||.||^|||^|^||.||^||.||^|^|^|||^|^|^|^|^|||^|||^|^|||^|^|........................
# .......................|^|^|^|^|^|^|^|^|^|.|.|^|^||.||^|^|||^|.||.|||.||^|^|^|^|^|^|^|^|||^|||^||.||^|^|^||.||^|^|||^|.......................
# ......................|^|^||.||^|||^|^|^|^|^|^|||^|.||.|.||^|^|^|^|||^|||^|^|^|||^|||^|||^|||^|^|.|^|||^|^|^|^|||^|||^|......................
# .....................|^|||^|.|^|||^|^|^|^||.||^|^||.||.|^|^||.|.||^|^|^|^|||^|^|^|^|^|||||^|^||.|.|.||^|^|^|^|||||^|^|^|.....................
# ....................|^|^|||^|^|^|^|^|^|^|^|^|^|^|^|^|^|^|^|^|.|^|^|||^||.||||^|^|||^|^|^|^||.||^|^|^||.||^|^|||||^||.||^|....................
# ...................|^|^|||^|^|||^|^|^|^|||^|^|||^|^|||^|||^|||^|^|^|^|||.|^|||^|^|^|^|^||.||.|||^|^|||^|||^|^|^|^|^|^|^|^|...................
# ..................|^|^|^|||^|^|^|^|^|^|||||^|||||^|^|^|^|^|||^|||^|^|||^|^|^|^|^|^|||^|||.|^|^|^|^|^|^|||^|^|||^|^|||^|^|^|..................
# .................|^|^|^|^|^|^|||^|^|^|^|^|^|^|^|||^|^||.|.||^|||||^|^|||^|^|^|^|^|^|||^|^|^|^|^|^||.||^||.|.||||^|^|||^|^|^|.................
# ................|^|^|||^|^|||^|^|^||.||^|||^|^|^|||^|||^|^||.||^|||^|||^|^|^|^||.||^|^|^|^||.||^|||^|^|^|^|.|||^|^|||^|^|^|^|................
# ...............|^|^|^|^|^|^|^|^||.||^|^|^|^|^||.||||^|^|||^|^|^|^|||^|||^|^||.||^|||^|^|^|^|^|^|||||^|||^|^|||^|^|||^|^|^|^|^|...............
# ..............|^|^|^|||^|^|||^|^|^|^|^|^|^|^|^|^|||^|^|||||^|||^|^||.||^|^|^|.|^|^|^|^|^|^|^|^|^|||||^|^|||^|||^|||||^|^|^|^|^|..............
# .............|^|^|||^|^|||^|^|^|^|^|^|^|^|||^|^|^|^|^|^|^|^|^|||^|^|^|^|||^|^|||^|||^|^|^||.||^|||^|^|||^|^|||^|^|||||^|^|^|||^|.............
# ............|^|^|^|||^|^|^|^|^|||^|^|^|||^|^|^|^|^|^|||^|^|^|||^|^|^|^||||.|.||^|^|^|^||.||^|^|^|||^|||^|^|||^|||^|^|^|^|^|^|^|^|............
# ...........|^|||^|^|||^|^|^|||^|||^|^|||^|^|^|^||.||^|^|^|^|^|^|||^|^|^|^|^|.|^|^|||^|^|^|^|^|^|^|||^|^|^|^|^||||.|.|.||^|||^|||^|...........
# ..........|^|||^||.||^|^|^|^|^|||^|^|^|^|^|||^|^|^|^|||^|||^||.||||^|||^|^|^|^|||^|^|^||.||^|^|^|||||^|||^|^|||||.|^|^|^|^|^|^|^|^|..........
# .........|^|^|^|^|^|^|^|^|^|^|^||.||^|^|||^|||^|||^|^|^|||||^|.|^|^|^|||^||.||^|||^|^|^|^|||^|^|^|^|^|^||.||^|^|^|^|^|^||.||^||.||^|.........
# ........|^|||^||.||^|^|^|^|||^|||^|^|^|||^|^|||^||.|.|.||^|^|^|^|^|^|||^|^|^||.||^|||^|^|^|||^|^|^||.|.||.||.||^|^|||^|^|.|^|||.|^|^|........
# .......|^|^|^|||^|^|^|^||.||^|^|^|^|^|^|^|^|^|^|||^|.|.|^|^||.||^|||^|^|^|||^|^||.||||^|||^|^|||^|||^|^|^|||^|^|^|^||.||^|||^|||^|^|^|.......
# ......|^|^||.|||.||^|^|^|^|^||.|.||^||.||^|||^|||||^|^|^|^|^|.|^|^|^|||^|||^|^|||.|^|^|^|^|^||||.||^||.||^|^|^|^|||^|.|^|||^|^|^|||^|^|......
# .....|^|^|||^|||^|^|^|^||.|.||^|^|^|^|^|||^|^|||^|||^|^|||^|^|||^|^|||^|^|^||.|||.||^|^|^|^|||^|^|^|||^|||^|||^|^|||^|^|^|^||.|.||^|^|^|.....
# ....|^|^|||^|||||^|^|||^|^|^||.||^|^|^|^|^|^|||||^|^|^|^|||^|^|^||.||^|^|^|||^|^|^|||^|^||.||^|||^|||^|^|||^|^|||^|^|^|^|^|^|^|^|^|||^|^|....
# ...|^|^|^|^|||^|^|^|^|^||.||^|^|^|^|^|||^||.||^|^|^|^|||^|^|^||.||.||.||^|^|^|||^|^|||^|^|^|||^|^|||||^|||^|^|||^|^|^|||^|^|^|^|^|||||^|^|...
# ..|^|^||.||^|||^|||^|^|||^|^|^|^|^|^|^||.||^|^|^|^|||^|^||.||^|.|^|^|^|^||.|.||^|^|^|||^||.||||^|||^|^|^|^|^|||||^|^|^|^|^|^|||^|^|^|^|^|^|..
# .|^|^|^|^|^|^|^|^||.||^|^|^|^|||^|^||.||^|^|||^|^|||^||.||.||.||^|||^|^|^|^|^|^|^|^|||^|^|.|^|^|^|||^|^|^|^|^|^|^|||^|^||.||^|^||.||^|^|^|^|.
# |^|^||.||^|^|^|||^|^|^|^|^|^|^|||^|^|.|^|^|||^|^|||^|^|^|||^|^|^|||^|^|^|||^||.||^|^|^|^|||^|^||.||^|||^|^|^||.||^|^|||^|^|^|^|||^|^|^|||^|^|

# %%
start_time = time.time()
for i in range(len(input[-1])): #m
    if input[-1][i] == "|":
        input[-1][i] = "1"
for j in range(len(input)-1,-1,-1): #n
    for i in range(len(input[j])): #m
        if input[j][i]=="|" and input[j+1][i]=="^":
            input[j][i] = str(int(input[j+1][i-1])+int(input[j+1][i+1]))
        if input[j][i]=="|" and input [j+1][i]!=".":
            input[j][i] = input[j+1][i]
# Complexity is O(m*n) :DDDDD
print(input[0][start])
end_time = time.time()
print(end_time-start_time) # no real time difference xD
# Out:
# 13418215871354
# 0.0025055408477783203

# %% [markdown]
# ## Day 8

# %% [markdown]
# ### Part 1

# %%
def eudist(r1,r2):
    eudist2 = 0
    for i in range(3):
        eudist2 += (r2[i]-r1[i])**2
    return eudist2

# %%
input = """162,817,812
57,618,57
906,360,560
592,479,940
352,342,300
466,668,158
542,29,236
431,825,988
739,650,466
52,470,668
216,146,977
819,987,18
117,168,530
805,96,715
346,949,466
970,615,88
941,993,340
862,61,35
984,92,344
425,690,689"""

with open("day8.txt") as f:
    input = f.read()

input = input.split("\n") # m*n
temp = []
for j in input: # n
    temp.append([int(i) for i in j.split(",")])
input = temp

# find the m smallest values in one side of the matrix of distances (no need to compute the whole matrix)
m=1000
min_distances = [(float('inf'), float('inf'), float('inf'))]*m
for j in range(len(input)): # n 
    for i in range(j+1, len(input)): #n/2
        distance = eudist(input[j],input[i])
        # we assume the min_distances is always sorted from largest to smallest
        idx = 0
        while idx<m and min_distances[idx][2]>distance: # m
            idx+=1
        if idx!=0:
            min_distances = min_distances[1:idx]+[(i,j,distance, input[i], input[j])]+min_distances[idx:]
print(min_distances)
# previous code has complexity n^2*m/2 (/2 for half matrix)

# create clusters of connected box
connected = []
for j in range(len(min_distances)): # m
    k = min_distances[j][0]
    v = min_distances[j][1]
    k_c = None
    v_c = None
    for i in range(len(connected)): # if all connected pair to pair, results in 500 clusters, so the mean would be 250 = m/4
        if k in connected[i]:
            k_c = i
        if v in connected[i]:
            v_c = i
        if v_c != None and k_c != None:
            break
    # case 1, none of the values appears in connected --> new cluster
    if k_c==None and v_c==None:
        connected.append([k,v])
    # case 2 and 3, only one of them appears in connectd --> Add the other one to the existing cluster
    if k_c==None and v_c!=None:
        connected[v_c].append(k)
    elif k_c!=None and v_c==None:
        connected[k_c].append(v)
    # case 4, when both are already part of same cluster --> Do nothing
    elif k_c!=None and k_c==v_c:
        None
    # case 5, when both are already part of different clusters --> Combine clusters
    elif k_c!=None and v_c!=None and k_c!=v_c: # reddundant if for clarification
        if k_c>v_c:
            l1 = connected.pop(k_c)
            l2 = connected.pop(v_c)
        else:
            l1 = connected.pop(v_c)
            l2 = connected.pop(k_c)
        connected.append(l1+l2)
# previous code has complexity m^2

# find the three largest clusters:
lengths = []
for i in connected: # k = len(connected)=300
    s = len(i)
    lengths.append(s)
lengths.sort() # k*log(k)
print(lengths[-3]*lengths[-2]*lengths[-1])
# Out:
# [(402, 226, 65940433, [40942, 48932, 88330], [47518, 45443, 85086]), (888, 617, 65902894, [37053, 62856, 54017], [43440, 66946, 56912]), (625, 347, 65870689, [1893, 1136, 58747], [8199, 3803, 54389]), (376, 374, 65865941, [73645, 78800, 71648], [74564, 79598, 79672]), (582, 49, 65834949, [84651, 48343, 52035], [92458, 46133, 52075]), (454, 408, 65809809, [50558, 92497, 37858], [42636, 92366, 36116]), (709, 230, 65755482, [23731, 23441, 68220], [15870, 25416, 68464]), (189, 14, 65732585, [54366, 71502, 91468], [51796, 65928, 96765]), (439, 127, 65686886, [15077, 97054, 7718], [17608, 95580, 15275]), (724, 491, 65633949, [9026, 92969, 89421], [12544, 98037, 84170]), (933, 872, 65577321, [16508, 31305, 29395], [18269, 23403, 29209]), (993, 537, 65560509, [42610, 48212, 96788], [43157, 45694, 89112]), (552, 314, 65533394, [21557, 30414, 93985], [26360, 27578, 88118]), (645, 611, 65436059, [82433, 95460, 25230], [86612, 97337, 18563]), (646, 118, 65359170, [32743, 19373, 80067], [24992, 17188, 80779]), (133, 120, 65320566, [86798, 18520, 42504], [78889, 16862, 42643]), (256, 143, 65289334, [87291, 60711, 27478], [80413, 57810, 30571]), (392, 308, 65129650, [64600, 14974, 62716], [57260, 18067, 64015]), (975, 761, 65031411, [85772, 71128, 19992], [89811, 74579, 13925]), (668, 642, 64989729, [62161, 4642, 67866], [68314, 1450, 71982]), (844, 411, 64916350, [89115, 25799, 49650], [85088, 29510, 55560]), (810, 190, 64906945, [61000, 4512, 42988], [61536, 5817, 35056]), (640, 314, 64894409, [30368, 23109, 82746], [26360, 27578, 88118]), (772, 559, 64730726, [51217, 33884, 57103], [54406, 27433, 60701]), (571, 115, 64685909, [9949, 111, 78502], [8102, 7937, 78670]), (585, 439, 64680494, [14656, 91927, 13900], [15077, 97054, 7718]), (471, 302, 64665381, [36592, 65898, 17382], [29879, 67424, 13226]), (342, 116, 64626933, [28471, 89378, 18690], [33695, 88297, 12676]), (838, 780, 64594910, [67788, 43858, 78090], [74898, 47507, 77237]), (839, 542, 64403625, [22723, 5081, 39649], [20349, 1831, 32706]), (881, 599, 64356749, [99376, 97060, 21814], [98451, 97170, 13846]), (842, 414, 64326242, [29831, 197, 78737], [33999, 3904, 84500]), (895, 403, 64242869, [92683, 15087, 6193], [84845, 13568, 6901]), (920, 511, 64204894, [16693, 11824, 8646], [20139, 5497, 5139]), (780, 394, 64141027, [74898, 47507, 77237], [69021, 46090, 82490]), (843, 124, 64112833, [47453, 90822, 35214], [54245, 93927, 32326]), (569, 506, 64051541, [59971, 69533, 84249], [58155, 77252, 85331]), (948, 468, 63969161, [51717, 19695, 91649], [55586, 15495, 97249]), (689, 632, 63961758, [29590, 89374, 49869], [34543, 95092, 52464]), (568, 334, 63879449, [78757, 9681, 95134], [70925, 11273, 95065]), (500, 373, 63872756, [85339, 12619, 18893], [89855, 18211, 15399]), (807, 295, 63869915, [86275, 58525, 39069], [80462, 62614, 42724]), (830, 270, 63852846, [5571, 35465, 53766], [8332, 40116, 59648]), (469, 113, 63836894, [9867, 73501, 58997], [4177, 69114, 55502]), (817, 80, 63829659, [23997, 65201, 64191], [30034, 64680, 58984]), (854, 358, 63816036, [83376, 73342, 52544], [82760, 81086, 50682]), (238, 230, 63773597, [22142, 30349, 68782], [15870, 25416, 68464]), (529, 317, 63698696, [10024, 5265, 26658], [11488, 6971, 19000]), (857, 574, 63656510, [6241, 73872, 8014], [7256, 81206, 10987]), (492, 304, 63655661, [85037, 7154, 70687], [91256, 9532, 75083]), (789, 452, 63640129, [54883, 78251, 39051], [57733, 74774, 32461]), (640, 310, 63636077, [30368, 23109, 82746], [30251, 29147, 77534]), (765, 246, 63593154, [86242, 90739, 42564], [78514, 90556, 44523]), (568, 331, 63548406, [78757, 9681, 95134], [76995, 2452, 92273]), (941, 556, 63519771, [70554, 9881, 31310], [71887, 8532, 23569]), (551, 305, 63359480, [9923, 15323, 17634], [13521, 8897, 14614]), (950, 197, 63292172, [40250, 3592, 96488], [37584, 10982, 97742]), (713, 292, 63263529, [19873, 72729, 57961], [22033, 70302, 50701]), (131, 121, 63242904, [40665, 71143, 63798], [48467, 72059, 62560]), (833, 187, 63224994, [12095, 39529, ...
# 133574

# %% [markdown]
# ### Part 2

# %%
import time

# %%
input = """162,817,812
57,618,57
906,360,560
592,479,940
352,342,300
466,668,158
542,29,236
431,825,988
739,650,466
52,470,668
216,146,977
819,987,18
117,168,530
805,96,715
346,949,466
970,615,88
941,993,340
862,61,35
984,92,344
425,690,689"""

with open("day8.txt") as f:
    input = f.read()



input = input.split("\n") # m*n
temp = []
for j in input: # n
    temp.append([int(i) for i in j.split(",")])
input = temp

start_time = time.time()

flat_distances = []
for j in range(len(input)): # n 
    for i in range(j+1, len(input)): #n/2
        distance = eudist(input[j],input[i])
        flat_distances.append((i,j,distance))
flat_distances.sort(key=lambda a:a[2]) # n logn


connected = []
idx = 0
while connected == [] or len(connected[0])<1000: # n^2
    current = flat_distances[idx]
    k = current[0]
    v = current[1]
    k_c = None
    v_c = None
    for i in range(len(connected)): # n
        if k in connected[i]:
            k_c = i
        if v in connected[i]:
            v_c = i
        if v_c != None and k_c != None:
            break
    # case 1, none of the values appears in connected --> new cluster
    if k_c==None and v_c==None:
        connected.append([k,v])
    # case 2 and 3, only one of them appears in connectd --> Add the other one to the existing cluster
    if k_c==None and v_c!=None:
        connected[v_c].append(k)
    elif k_c!=None and v_c==None:
        connected[k_c].append(v)
    # case 4, when both are already part of same cluster --> Do nothing
    elif k_c!=None and k_c==v_c:
        None
    # case 5, when both are already part of different clusters --> Combine clusters
    elif k_c!=None and v_c!=None and k_c!=v_c: # reddundant if for clarification
        if k_c>v_c:
            l1 = connected.pop(k_c)
            l2 = connected.pop(v_c)
        else:
            l1 = connected.pop(v_c)
            l2 = connected.pop(k_c)
        connected.append(l1+l2)
    idx+=1
#O(n^3)

print(k, v)
print(input[k][0]*input[v][0])

end_time = time.time()
print(end_time-start_time)
# Out:
# 925 490
# 2435100380
# 0.6365189552307129

# %% [markdown]
# Trying to use DSU to optimize

# %%
with open("day8.txt") as f:
    input = f.read()

input = input.split("\n") # m*n
temp = []
for j in input: # n
    temp.append([int(i) for i in j.split(",")])
input = temp

start_time = time.time()

flat_distances = []
for j in range(len(input)): # n 
    for i in range(j+1, len(input)): #n/2
        distance = eudist(input[j],input[i])
        flat_distances.append((i,j,distance))
flat_distances.sort(key=lambda a:a[2]) # n logn


dsu = [i for i in range(len(input))]
sizes = [1 for i in range(len(input))]
idx=0
while True:
    current = flat_distances[idx]
    k = int(current[0])
    v = int(current[1])
    while dsu[k] != k:
        k = dsu[k]
    while dsu[v] != v:
        v = dsu[v]
    if k!=v:
        dsu[k] = v
        sizes[v] += sizes[k]
        if sizes[v]==len(input):
            break
    idx+=1

final = flat_distances[idx]
print(input[final[0]][0]*input[final[1]][0])

end_time = time.time()
print(end_time-start_time)
# time complexity is now governed by nlog(n) but there is no improvement in this case
# Out:
# 2435100380
# 0.5742361545562744
